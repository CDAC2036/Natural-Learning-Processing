# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

# %%
image = load_img('/content/Hilter.jpg', target_size=(224, 224))
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
type(image)
# Out:
# PIL.Image.Image

# %%
image = img_to_array(image)
image
# Out:
# array([[[ 57.,  57.,  57.],
#         [ 50.,  50.,  50.],
#         [ 50.,  50.,  50.],
#         ...,
#         [101., 101., 101.],
#         [101., 101., 101.],
#         [102., 102., 102.]],
#
#        [[ 60.,  60.,  60.],
#         [ 52.,  52.,  52.],
#         [ 50.,  50.,  50.],
#         ...,
#         [ 99.,  99.,  99.],
#         [ 98.,  98.,  98.],
#         [ 99.,  99.,  99.]],
#
#        [[ 67.,  67.,  67.],
#         [ 57.,  57.,  57.],
#         [ 53.,  53.,  53.],
#         ...,
#         [100., 100., 100.],
#         [100., 100., 100.],
#         [101., 101., 101.]],
#
#        ...,
#
#        [[ 35.,  35.,  35.],
#         [ 30.,  30.,  30.],
#         [ 31.,  31.,  31.],
#         ...,
#         [ 82.,  82.,  82.],
#         [ 95.,  95.,  95.],
#         [142., 142., 142.]],
#
#        [[ 50.,  50.,  50.],
#         [ 43.,  43.,  43.],
#         [ 39.,  39.,  39.],
#         ...,
#         [ 77.,  77.,  77.],
#         [114., 114., 114.],
# ...

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
# Reshape data for the model

image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image.shape
# Out:
# (1, 224, 224, 3)

# %%
# Prepare the image for the VGG Model
# tf.keras.applications.imagenet_utils.preprocess_input(x, data_format=None, mode='caffe'): Preprocesses a tensor or Numpy array encoding a batch of images.

image = preprocess_input(image)

# %%
model = VGG16()

# %%
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
yhat
# Out:
# array([[1.26043471e-06, 3.32734771e-07, 7.28553459e-07, 1.21175185e-06,
#         1.44491651e-06, 6.24549841e-07, 6.37752919e-07, 7.39491406e-06,
#         1.02823958e-06, 2.34149589e-08, 8.71527845e-07, 4.67189352e-07,
#         5.32634431e-07, 6.95810741e-07, 4.33786738e-07, 1.58830872e-07,
#         5.77831827e-07, 1.32445882e-06, 1.14721877e-06, 6.35798074e-07,
#         1.69561588e-07, 3.71448522e-07, 1.04417313e-06, 8.60932403e-07,
#         1.08604263e-06, 2.97109494e-07, 9.17274079e-08, 3.70236876e-07,
#         9.78202593e-07, 1.50302924e-07, 3.00791243e-07, 3.69596222e-07,
#         2.34261606e-07, 1.24776506e-07, 4.23696861e-07, 1.48551976e-07,
#         2.87051478e-07, 3.98578322e-07, 2.62964733e-07, 6.26714495e-07,
#         1.02186789e-06, 2.24447604e-07, 2.08774082e-07, 1.35102061e-06,
#         5.71327632e-07, 5.38186214e-07, 8.20722846e-07, 1.59347181e-07,
#         1.57393870e-07, 1.99282212e-07, 2.48750013e-07, 1.84353908e-07,
# ...

# %%
yhat.shape
# Out:
# (1, 1000)

# %%
# tf.keras.applications.imagenet_utils.decode_predictions(preds, top=5): Decodes the prediction of an ImageNet model.

a = decode_predictions(yhat)
a
# Out:
# [[('n04350905', 'suit', 0.36050543),
#   ('n04479046', 'trench_coat', 0.25891086),
#   ('n03763968', 'military_uniform', 0.20897153),
#   ('n04591157', 'Windsor_tie', 0.07057186),
#   ('n02883205', 'bow_tie', 0.033329587)]]
